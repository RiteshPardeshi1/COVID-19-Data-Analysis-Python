# %% [markdown]
# # COVID-19 DATA ANALYSIS

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize']= 17,8

import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

import cufflinks as cf
import folium

# %%
pyo.init_notebook_mode(connected =True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_excel(r"C:\Users\LENOVO\Desktop\Transference certificate\COVID-19-Data-Analyisis-master\COVID-19-Data-Analyisis-master\Covid cases in India.xlsx")

# %%
df
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# ...

# %% [markdown]
# Removing 'S. No.' Column

# %%
df.drop(['S. No.'],axis=1,inplace=True )

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %% [markdown]
# Lets, see the total number of cases ADDING total cases column

# %%
df['Total Cases'] = df['Total Confirmed cases (Indian National)'] + df['Total Confirmed cases ( Foreign National )']

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %% [markdown]
#  **Adding Total Active Cases Column**

# %%
df['Active cases'] = df['Total Cases'] - (df['Death']+df['Cured'])

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %% [markdown]
#  **Adding Style Background Gradient**

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_dd93ebdb_a971_11eb_b230_142d27e816e6row0_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_dd93ebdb_a971_11eb_b230_142d27e816e6row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_dd93ebdb_a971_11eb_b230_142d27e816e6row0_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_dd93ebdb_a971_11eb_b230_142d27e816e6row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_dd93ebdb_a971_11eb_b230_142d27e816e6row0_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_dd93ebdb_a971_11eb_b230_142d27e816e6row0_col6 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_dd93ebdb_a971_11eb_b230_142d27e816e6row1_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
# ...

# %%
total_active_cases = df.groupby('Name of State / UT')['Active cases'].sum().sort_values(ascending = False).to_frame()

# %%
total_active_cases
# Out:
#                     Active cases
# Name of State / UT
# Maharashtra                  128
# Kerala                       127
# Telengana                     44
# Rajasthan                     40
# Gujarat                       40
# Tamil Nadu                    33
# Uttar Pradesh                 32
# Delhi                         32
# Punjab                        28
# Madhya Pradesh                22
# Haryana                       19
# Jammu and Kashmir             16
# Karnataka                     15
# Ladakh                        13
# Andhra Pradesh                11
# West Bengal                   10
# Chandigarh                     7
# Goa                            6
# Chhattisgarh                   6
# Bihar                          6
# Uttarakhand                    4
# Himachal Pradesh               3
# Odisha                         3
# Manipur                        1
# Mizoram                        1
# Puducherry                     1

# %%
total_active_cases.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_251120b5_a975_11eb_89e4_142d27e816e6row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_251120b5_a975_11eb_89e4_142d27e816e6row1_col0 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_251120b5_a975_11eb_89e4_142d27e816e6row2_col0 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_251120b5_a975_11eb_89e4_142d27e816e6row3_col0 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_251120b5_a975_11eb_89e4_142d27e816e6row4_col0 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_251120b5_a975_11eb_89e4_142d27e816e6row5_col0 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_251120b5_a975_11eb_89e4_142d27e816e6row6_col0 {
#             background-color:  #fcbda4;
#             color:  #000000;
# ...

# %% [markdown]
# **Some Graphical Presentation after numerical
#  -- Presentation of Total Cases**

# %%
#pandas visualization

# %%
df.plot(kind='bar',x='Name of State / UT',y='Total Cases')

# %%
#Matplotlib visualization

# %%
plt.bar(df['Name of State / UT'],df['Total Cases'])
plt.tight_layout()

# %%
df.iplot(kind='bar',x='Name of State / UT',y='Total Cases')
# Out:
# <div>                            <div id="df9ca3e3-0acb-4789-8121-6a2d1d1c3bc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
px.bar(df,x='Name of State / UT',y='Total Cases')
# Out:
# <div>                            <div id="171ee424-113c-4b9d-a7c8-d8015c4ddfb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("171ee424-113c-4b9d-a7c8-d8015c4ddfb0")) {                    Plotly.newPlot(                        "171ee424-113c-4b9d-a7c8-d8015c4ddfb0",                        [{"alignmentgroup": "True", "hovertemplate": "Name of State / UT=%{x}<br>Total Cases=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tami
# ...

# %% [markdown]
# # More Visualization

# %%
#Pandas

# %%
df.plot(kind='scatter',x='Name of State / UT',y='Total Cases',title="Total Cases",colormap='coolwarm')

# %%
#matplotlib

# %%
plt.scatter(df['Name of State / UT'],df['Total Cases'],marker='+',color='orange')
plt.tight_layout()

# %%
#plotly

# %%
df.iplot(kind='scatter',x='Name of State / UT',y='Total Cases',mode='markers+lines',title='state-wise',xTitle='states',yTitle='Total cases',color='red',size=20)
# Out:
# <div>                            <div id="8a483458-271d-45bf-b575-980d717e6136" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
px.scatter(df,x='Name of State / UT', y= 'Total Cases')
# Out:
# <div>                            <div id="d309f770-144d-446a-bd11-6a52957cc3f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d309f770-144d-446a-bd11-6a52957cc3f9")) {                    Plotly.newPlot(                        "d309f770-144d-446a-bd11-6a52957cc3f9",                        [{"hovertemplate": "Name of State / UT=%{x}<br>Total Cases=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Cha
# ...

# %% [markdown]
# **using Object oriented method for visualization**

# %%
#matplotlib

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.bar(df['Name of State / UT'],df['Total Cases'])
axes.set_title=('Total Cases in India')
axes.set_xlabel=('States')
axes.set_ylabel =('Total Cases')
plt.show()

# %%
#plotly

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=df['Name of State / UT'],y=df['Active cases']))
fig.update_layout(title='Total Cases in India',xaxis=dict(title='States'),yaxis=dict(title='Active cases'))
# Out:
# <div>                            <div id="1ec3c69a-35f2-4f86-b6da-7dada788e55c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ec3c69a-35f2-4f86-b6da-7dada788e55c")) {                    Plotly.newPlot(                        "1ec3c69a-35f2-4f86-b6da-7dada788e55c",                        [{"type": "bar", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Chandigarh", "Jammu and Kashmir", "Ladakh", "Uttar Pradesh", "Uttarakhand", "West Bengal", "Bihar", "Mizoram", "Goa", "Manipur"], "y": [11, 6, 32, 40, 19, 3, 15, 127, 22, 128, 3, 1, 28, 40, 33, 44, 7, 16, 13, 32, 4, 10, 6, 1, 6, 
# ...

# %% [markdown]
# **Visualizing with the help of map, Importing another file namely "indian coordinates" that contain all the states coordinates**

# %%
indian_cord = pd.read_excel("Indian Coordinates.xlsx")

# %%
indian_cord
# Out:
#                       Name of State / UT   Latitude  Longitude
# 0                   Andaman And Nicobar   11.667026  92.735983
# 1                         Andhra Pradesh  14.750429  78.570026
# 2                     Arunachal Pradesh   27.100399  93.616601
# 3                                 Assam   26.749981  94.216667
# 4                                 Bihar   25.785414  87.479973
# 5                            Chandigarh   30.719997  76.780006
# 6                          Chhattisgarh   22.090420  82.159987
# 7                Dadra And Nagar Haveli   20.266578  73.016618
# 8                                  Delhi  28.669993  77.230004
# 9                                   Goa   15.491997  73.818001
# 10                               Haryana  28.450006  77.019991
# 11                     Himachal Pradesh   31.100025  77.166597
# 12  Union Territory of Jammu and Kashmir  33.450000  76.240000
# 13                            Jharkhand   23.800393  86.419986
# ...

# %%
df_full = pd.merge(indian_cord,df,on='Name of State / UT')

# %%
df_full
# Out:
#    Name of State / UT   Latitude  Longitude  \
# 0      Andhra Pradesh  14.750429  78.570026
# 1               Delhi  28.669993  77.230004
# 2             Haryana  28.450006  77.019991
# 3           Karnataka  12.570381  76.919997
# 4              Kerala   8.900373  76.569993
# 5         Maharashtra  19.250232  73.160175
# 6              Punjab  31.519974  75.980003
# 7           Rajasthan  26.449999  74.639981
# 8           Telengana  18.112400  79.019300
# 9          Tamil Nadu  12.920386  79.150042
# 10      Uttar Pradesh  27.599981  78.050006
# 11        Uttarakhand  30.320409  78.050006
#
#     Total Confirmed cases (Indian National)  \
# 0                                        12
# 1                                        38
# 2                                        16
# 3                                        20
# 4                                       131
# 5                                       144
# 6                                        29
# ...

# %%
map=folium.Map(location=[20,70],zoom_start=4,tiles='Stamenterrain')

for lat,long,value, name in zip(df_full['Latitude'],df_full['Longitude'],df_full['Total Cases'],df_full['Name of State / UT']):
    folium.CircleMarker([lat,long],radius=value*0.8,popup=('<strong>State</strong>: '+str(name).capitalize()+'<br>''<strong>Total Cases</strong>: ' + str(value)+ '<br>'),color='red',fill_color='red',fill_opacity=0.3).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Importing "per_day_case" File for more visualization.

# %%
dbd_india = pd.read_excel("per_day_cases.xlsx",parse_date=True,sheet_name='India')
dbd_italy = pd.read_excel("per_day_cases.xlsx",parse_date=True,sheet_name='Italy')
dbd_korea = pd.read_excel("per_day_cases.xlsx",parse_date=True,sheet_name='Korea')
dbd_wuhan = pd.read_excel("per_day_cases.xlsx",parse_date=True,sheet_name='Wuhan')

# %%
dbd_wuhan
# Out:
#          Date  Total Cases  New Cases
# 0  2020-01-22          444          0
# 1  2020-01-23          444          0
# 2  2020-01-24          549        105
# 3  2020-01-25          761        212
# 4  2020-01-26         1058        297
# 5  2020-01-27         1423        365
# 6  2020-01-28         3554       2131
# 7  2020-01-29         3554          0
# 8  2020-01-30         4903       1349
# 9  2020-01-31         5806        903
# 10 2020-01-02         7153       1347
# 11 2020-02-02        11177       4024
# 12 2020-02-03        13522       2345
# 13 2020-02-04        16678       3156
# 14 2020-02-05        19665       2987
# 15 2020-02-06        22112       2447
# 16 2020-02-07        24953       2841
# 17 2020-02-08        27100       2147
# 18 2020-02-09        29631       2531
# 19 2020-02-10        31728       2097
# 20 2020-02-11        33366       1638
# 21 2020-02-12        33366          0
# 22 2020-02-13        48206      14840
# 23 2020-02-14        54406       6200
# ...

# %% [markdown]
# **Data analysis of countries using matplotlib and plotly**

# %%
#matplotlib
fig = plt.figure(figsize=(10,5),dpi=200)
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.bar(dbd_india['Date'],dbd_india['Total Cases'],color='blue')
axes.set_title("Confirmed cases in India")
axes.set_xlabel("Date")
axes.set_ylabel("Total cases")
plt.show()

# %%
#ploty express
fig = px.bar(dbd_india,x='Date',y='Total Cases',color='Total Cases',title='Confirmed cases in India')
fig.show()
# Out:
# <div>                            <div id="59b9e08a-23c9-4e63-afaa-daed6e65542e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59b9e08a-23c9-4e63-afaa-daed6e65542e")) {                    Plotly.newPlot(                        "59b9e08a-23c9-4e63-afaa-daed6e65542e",                        [{"alignmentgroup": "True", "hovertemplate": "Date=%{x}<br>Total Cases=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [1, 1, 1, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 6, 9, 28, 30, 31, 34, 39, 43, 56, 62, 73, 82, 102, 113, 119, 142, 156, 194, 244, 271], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x"
# ...

# %%
#italy
fig = px.bar(dbd_italy,x='Date',y='Total Cases',color='Total Cases',title='Confirmed cases in Italy')
fig.show()
#korea
fig = px.bar(dbd_korea,x='Date',y='Total Cases',color='Total Cases',title='Confirmed cases in Korea')
fig.show()
#wuhan
fig = px.bar(dbd_wuhan,x='Date',y='Total Cases',color='Total Cases',title='Confirmed cases in Wuhan')
fig.show()
# Out:
# <div>                            <div id="2dccff76-d13a-46bc-bd29-d2fce61ad40d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dccff76-d13a-46bc-bd29-d2fce61ad40d")) {                    Plotly.newPlot(                        "2dccff76-d13a-46bc-bd29-d2fce61ad40d",                        [{"alignmentgroup": "True", "hovertemplate": "Date=%{x}<br>Total Cases=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 20, 79, 157, 229, 323, 470, 655, 889, 1128, 1701, 2036, 2502, 3089, 3858, 4636, 5883, 7375, 9172, 10149, 12462, 15113, 17660, 21157, 24747, 27980, 31506, 35713, 41035, 47021], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "sho
# ...

# %%
#Scatter plot

# %%
fig = plt.figure(figsize=(10,8),dpi=100)
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.scatter(dbd_india['Date'],dbd_india['Total Cases'],color='red')
axes.set_title('Confirmed cases in India')
axes.set_xlabel('Date')
axes.set_ylabel('Total cases')
plt.show()

# %%
#plotly express
fig = px.scatter(dbd_india,x='Date',y='Total Cases',color='Total Cases',title='Confirmed cases in India')
fig.show()
# Out:
# <div>                            <div id="cb893aef-0833-4f87-817f-975f420b8579" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb893aef-0833-4f87-817f-975f420b8579")) {                    Plotly.newPlot(                        "cb893aef-0833-4f87-817f-975f420b8579",                        [{"hovertemplate": "Date=%{x}<br>Total Cases=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [1, 1, 1, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 6, 9, 28, 30, 31, 34, 39, 43, 56, 62, 73, 82, 102, 113, 119, 142, 156, 194, 244, 271], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-01-30T00:00:00", 
# ...

# %%
#plotly
dbd_india.iplot(kind='scatter',x='Date',y='Total Cases',mode='lines+markers',xTitle='Dates',yTitle='Total cases')
# Out:
# <div>                            <div id="157a7a1d-0ecb-4b62-ba2e-14f0348dd0ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#plotly graph_object

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dbd_india['Date'],y=dbd_india['Total Cases'],mode='lines+markers'))
# Out:
# <div>                            <div id="9b24aed9-a586-4988-b864-9983bff0e805" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b24aed9-a586-4988-b864-9983bff0e805")) {                    Plotly.newPlot(                        "9b24aed9-a586-4988-b864-9983bff0e805",                        [{"mode": "lines+markers", "type": "scatter", "x": ["2020-01-30T00:00:00", "2020-01-31T00:00:00", "2020-02-01T00:00:00", "2020-02-02T00:00:00", "2020-02-03T00:00:00", "2020-02-04T00:00:00", "2020-02-05T00:00:00", "2020-02-06T00:00:00", "2020-02-07T00:00:00", "2020-02-08T00:00:00", "2020-02-09T00:00:00", "2020-02-10T00:00:00", "2020-02-11T00:00:00", "2020-02-12T00:00:00", "2020-02-13T00:00:00", "2020-02-14T00:00:00", "2020-02-15T00:00:00", "2020-02-16T00:00:00", "2
# ...

# %%
#subplot using bar graph

# %%
from plotly.subplots import make_subplots

# %%
fig= make_subplots(rows=2,cols=2,specs=[[{"secondary_y":True},{"secondary_y":True}],[{"secondary_y":True},{"secondary_y":True}]],
    subplot_titles=("S.Korea","Italy","India","Wuhan"))
fig.add_trace(go.Bar(x=dbd_korea['Date'],y=dbd_korea['Total Cases'],
                     marker=dict(color=dbd_korea['Total Cases'],coloraxis="coloraxis")),1,1)

fig.add_trace(go.Bar(x=dbd_italy['Date'],y=dbd_italy['Total Cases'],
                    marker=dict(color=dbd_italy['Total Cases'],coloraxis="coloraxis")),1,2)

fig.add_trace(go.Bar(x=dbd_india['Date'],y=dbd_india['Total Cases'],
                    marker=dict(color=dbd_india['Total Cases'],coloraxis="coloraxis")),2,1)

fig.add_trace(go.Bar(x=dbd_wuhan['Date'],y=dbd_wuhan['Total Cases'],
                    marker=dict(color=dbd_wuhan['Total Cases'],coloraxis="coloraxis")),2,2)

fig.update_layout(title="Total cases in 4 countries",showlegend=False)
# Out:
# <div>                            <div id="b1031a44-b6d4-4c71-9f12-8e7cc9d0a7bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1031a44-b6d4-4c71-9f12-8e7cc9d0a7bc")) {                    Plotly.newPlot(                        "b1031a44-b6d4-4c71-9f12-8e7cc9d0a7bc",                        [{"marker": {"color": [1, 1, 1, 1, 2, 2, 3, 4, 4, 4, 6, 11, 12, 15, 15, 16, 19, 23, 24, 24, 27, 27, 28, 28, 28, 28, 28, 29, 30, 31, 58, 111, 209, 436, 602, 833, 977, 1261, 1766, 2337, 3150, 3736, 4335, 5186, 5621, 6284, 6593, 7041, 7313, 7478, 7513, 7755, 7869, 7979, 8086, 8162, 8236, 8320, 8413, 8565, 8652], "coloraxis": "coloraxis"}, "type": "bar", "x": ["2020-01-20T00:00:00", "2020-01-21T00:00:00", "2020-01-22T00:00:00", "2020-01-23T00:00:00", "2020-01-24T00:00
# ...

# %%
#scatter plot (subplot)

# %%
fig = make_subplots(rows=2,cols=2,specs=[[{"secondary_y":True},{"secondary_y":True}],[{"secondary_y":True},{"secondary_y":True}]],
                  subplot_titles=("S.Korea","Italy","India","Wuhan"))
fig.add_trace(go.Scatter(x=dbd_korea['Date'],y=dbd_korea['Total Cases'],
                        marker=dict(color=dbd_korea['Total Cases'],coloraxis='coloraxis')),1,1)
fig.add_trace(go.Scatter(x=dbd_italy['Date'],y=dbd_italy['Total Cases'],
                        marker=dict(color=dbd_italy['Total Cases'],coloraxis='coloraxis')),1,2)
fig.add_trace(go.Scatter(x=dbd_india['Date'],y=dbd_india['Total Cases'],
                    marker=dict(color=dbd_india['Total Cases'],coloraxis="coloraxis")),2,1)

fig.add_trace(go.Scatter(x=dbd_wuhan['Date'],y=dbd_wuhan['Total Cases'],
                    marker=dict(color=dbd_wuhan['Total Cases'],coloraxis="coloraxis")),2,2)

fig.update_layout(title="Total cases in 4 countries",showlegend=False)
# Out:
# <div>                            <div id="7464b90f-4bb8-44a3-9610-38a32c99b96b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7464b90f-4bb8-44a3-9610-38a32c99b96b")) {                    Plotly.newPlot(                        "7464b90f-4bb8-44a3-9610-38a32c99b96b",                        [{"marker": {"color": [1, 1, 1, 1, 2, 2, 3, 4, 4, 4, 6, 11, 12, 15, 15, 16, 19, 23, 24, 24, 27, 27, 28, 28, 28, 28, 28, 29, 30, 31, 58, 111, 209, 436, 602, 833, 977, 1261, 1766, 2337, 3150, 3736, 4335, 5186, 5621, 6284, 6593, 7041, 7313, 7478, 7513, 7755, 7869, 7979, 8086, 8162, 8236, 8320, 8413, 8565, 8652], "coloraxis": "coloraxis"}, "type": "scatter", "x": ["2020-01-20T00:00:00", "2020-01-21T00:00:00", "2020-01-22T00:00:00", "2020-01-23T00:00:00", "2020-01-24T0
# ...

# %% [markdown]
# # World-wise COVID-19 Analysis

# %% [markdown]
# **importing files**

# %%
df= pd.read_csv("covid_19_data.csv",parse_dates=['Last Update'])

# %%
df
# Out:
#        SNo ObservationDate                Province/State  \
# 0        1      01/22/2020                         Anhui
# 1        2      01/22/2020                       Beijing
# 2        3      01/22/2020                     Chongqing
# 3        4      01/22/2020                        Fujian
# 4        5      01/22/2020                         Gansu
# ...    ...             ...                           ...
# 5885  5886      03/15/2020                     Gibraltar
# 5886  5887      03/15/2020                           NaN
# 5887  5888      03/15/2020  Diamond Princess cruise ship
# 5888  5889      03/15/2020                 West Virginia
# 5889  5890      03/15/2020                           NaN
#
#                       Country/Region         Last Update  Confirmed  Deaths  \
# 0                     Mainland China 2020-01-22 17:00:00        1.0     0.0
# 1                     Mainland China 2020-01-22 17:00:00       14.0     0.0
# ...

# %%
df.rename(columns={'ObservationDate':'date','Country/Region':'country'},inplace=True)

# %%
df
# Out:
#        SNo        date                Province/State  \
# 0        1  01/22/2020                         Anhui
# 1        2  01/22/2020                       Beijing
# 2        3  01/22/2020                     Chongqing
# 3        4  01/22/2020                        Fujian
# 4        5  01/22/2020                         Gansu
# ...    ...         ...                           ...
# 5885  5886  03/15/2020                     Gibraltar
# 5886  5887  03/15/2020                           NaN
# 5887  5888  03/15/2020  Diamond Princess cruise ship
# 5888  5889  03/15/2020                 West Virginia
# 5889  5890  03/15/2020                           NaN
#
#                              country         Last Update  Confirmed  Deaths  \
# 0                     Mainland China 2020-01-22 17:00:00        1.0     0.0
# 1                     Mainland China 2020-01-22 17:00:00       14.0     0.0
# 2                     Mainland China 2020-01-22 17:00:00        6.0     0.0
# ...

# %%
df.query('country=="India"')
# Out:
#        SNo        date Province/State country         Last Update  Confirmed  \
# 430    431  01/30/2020            NaN   India 2020-01-30 16:00:00        1.0
# 491    492  01/31/2020            NaN   India 2020-01-31 23:59:00        1.0
# 547    548  02/01/2020            NaN   India 2020-01-31 08:15:00        1.0
# 607    608  02/02/2020            NaN   India 2020-02-02 06:03:08        2.0
# 672    673  02/03/2020            NaN   India 2020-02-03 21:43:02        3.0
# 740    741  02/04/2020            NaN   India 2020-02-03 21:43:02        3.0
# 810    811  02/05/2020            NaN   India 2020-02-03 21:43:02        3.0
# 881    882  02/06/2020            NaN   India 2020-02-03 21:43:02        3.0
# 954    955  02/07/2020            NaN   India 2020-02-03 21:43:02        3.0
# 1026  1027  02/08/2020            NaN   India 2020-02-03 21:43:02        3.0
# 1098  1099  02/09/2020            NaN   India 2020-02-03 21:43:02        3.0
# ...

# %%
#Summing up the whole confirmed,death,recovered at a particular dates using groupby

# %%
df.groupby('date').sum()
# Out:
#                 SNo  Confirmed  Deaths  Recovered
# date
# 01/22/2020      741      555.0    17.0       28.0
# 01/23/2020     2829      653.0    18.0       30.0
# 01/24/2020     4305      941.0    26.0       36.0
# 01/25/2020     6490     1438.0    42.0       39.0
# 01/26/2020     9071     2118.0    56.0       52.0
# 01/27/2020    12342     2927.0    82.0       61.0
# 01/28/2020    15262     5578.0   131.0      107.0
# 01/29/2020    18711     6165.0   133.0      126.0
# 01/30/2020    23345     8235.0   171.0      143.0
# 01/31/2020    28675     9925.0   213.0      222.0
# 02/01/2020    35309    12038.0   259.0      284.0
# 02/02/2020    39798    16787.0   362.0      472.0
# 02/03/2020    44982    19881.0   426.0      623.0
# 02/04/2020    51135    23892.0   492.0      852.0
# 02/05/2020    56871    27636.0   564.0     1124.0
# 02/06/2020    61912    30818.0   634.0     1487.0
# 02/07/2020    67932    34392.0   719.0     2011.0
# 02/08/2020    73116    37121.0   806.0     2616.0
# ...

# %% [markdown]
# **using graph_object method for visualization**

# %%
confirmed=df.groupby('date').sum()['Confirmed'].reset_index()
death=df.groupby('date').sum()['Deaths'].reset_index()
rec=df.groupby('date').sum()['Recovered'].reset_index()

# %%
confirmed
# Out:
#           date  Confirmed
# 0   01/22/2020      555.0
# 1   01/23/2020      653.0
# 2   01/24/2020      941.0
# 3   01/25/2020     1438.0
# 4   01/26/2020     2118.0
# 5   01/27/2020     2927.0
# 6   01/28/2020     5578.0
# 7   01/29/2020     6165.0
# 8   01/30/2020     8235.0
# 9   01/31/2020     9925.0
# 10  02/01/2020    12038.0
# 11  02/02/2020    16787.0
# 12  02/03/2020    19881.0
# 13  02/04/2020    23892.0
# 14  02/05/2020    27636.0
# 15  02/06/2020    30818.0
# 16  02/07/2020    34392.0
# 17  02/08/2020    37121.0
# 18  02/09/2020    40151.0
# 19  02/10/2020    42763.0
# 20  02/11/2020    44803.0
# 21  02/12/2020    45222.0
# 22  02/13/2020    60370.0
# 23  02/14/2020    66887.0
# 24  02/15/2020    69032.0
# 25  02/16/2020    71226.0
# 26  02/17/2020    73260.0
# 27  02/18/2020    75138.0
# 28  02/19/2020    75641.0
# 29  02/20/2020    76199.0
# 30  02/21/2020    76843.0
# 31  02/22/2020    78599.0
# 32  02/23/2020    78985.0
# 33  02/24/2020    79570.0
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=confirmed['date'],y=confirmed['Confirmed'],mode='lines+markers',name='Confirmed',line=dict(color='blue',width=2)))

fig.add_trace(go.Scatter(x=death['date'],y=death['Deaths'],mode='lines+markers',name='Deaths',line=dict(color='red',width=2)))
fig.add_trace(go.Scatter(x=rec['date'],y=rec['Recovered'],mode='lines+markers',name='Recovered',line=dict(color='green',width=2)))
# Out:
# <div>                            <div id="6c444e57-67f0-424c-b70f-63a563225cd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c444e57-67f0-424c-b70f-63a563225cd1")) {                    Plotly.newPlot(                        "6c444e57-67f0-424c-b70f-63a563225cd1",                        [{"line": {"color": "blue", "width": 2}, "mode": "lines+markers", "name": "Confirmed", "type": "scatter", "x": ["01/22/2020", "01/23/2020", "01/24/2020", "01/25/2020", "01/26/2020", "01/27/2020", "01/28/2020", "01/29/2020", "01/30/2020", "01/31/2020", "02/01/2020", "02/02/2020", "02/03/2020", "02/04/2020", "02/05/2020", "02/06/2020", "02/07/2020", "02/08/2020", "02/09/2020", "02/10/2020", "02/11/2020", "02/12/2020", "02/13/2020", "02/14/2020", "02/15/2020", "02/16
# ...

# %% [markdown]
# # Thank you
